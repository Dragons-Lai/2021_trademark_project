# %%
from bs4 import BeautifulSoup
import requests
import os

# %%
para = {'applNo':"104056467",'showType':"2",'caseType':"1"}
html = requests.post(url = "https://twtmsearch.tipo.gov.tw/SS0/SS0201.jsp",data = para)
soup = BeautifulSoup(html.text, 'html.parser')
print(soup.prettify())
x = html.text
print(html.headers)
with open ("t.html","w",encoding="UTF-8") as f:
    f.write(x)
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    智慧局商標檢索系統
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="-1" http-equiv="Expires">
#    <meta content="no-cache" http-equiv="pragma"/>
#    <meta content="no-cache" http-equiv="Cache-control"/>
#    <meta content="智慧局商標檢索系統" name="keywords"/>
#    <link href="/css/default.css;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz" rel="stylesheet" type="text/css"/>
#    <link href="/js/jquery-window-5.0.4/css/jquery.window.css;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz" rel="stylesheet" type="text/css"/>
#    <link href="/favicon.ico;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz" rel="shortcut icon"/>
#    <script src="/jqwidgets/scripts/jquery-1.11.1.min.js;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz">
#    </script>
#    <script src="/js/tablesort.js;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz" type="text/javascript">
#    </script>
#    <script src="/js/validate.js;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz" type="text/javascript">
#    </script>
#    <script src="/js/function.js;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz" type="text/javascript">
#    </script>
#    <script src="/js/json.js;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz" type="text/javascript">
#    </script>
#    <script src="/js/jquery/jquery-cookie.js;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz" type="text/javascript">
#    </script>
#    <script src="/js/commonUtils.js;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz" type="text/javascript">
#    </script>
#    <script src="/js/md5.js;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz" type="text/javascript">
#    </script>
#    <script src="/js/handlebars-v4.0.2.js;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz" type="text/javascript">
#    </script>
#    <script src="/js/lb0901.js;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz" type="text/javascript">
#    </script>
#    <script src="/js/jquery-window-5.0.4/jquery.window.min.js;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz" type="text/javascript">
#    </script>
#    <script src="/js/tcfifunction.js;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz" type="text/javascript">
#    </script>
#    <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#    <meta content="-1" http-equiv="Expires"/>
#    <meta content="no-cache" http-equiv="pragma"/>
#    <meta content="no-cache" http-equiv="Cache-control"/>
#    <script src="../js/tablesort.js" type="text/javascript">
#    </script>
#    <script src="../js/validate.js" type="text/javascript">
#    </script>
#    <script src="../js/function.js" type="text/javascript">
#    </script>
#    <script src="../js/jquery.js" type="text/javascript">
#    </script>
#    <script src="../js/json.js" type="text/javascript">
#    </script>
#    <script src="../js/jquery.ba-serializeobject.min.js" type="text/javascript">
#    </script>
#    <script src="../js/jquery.deserialize.js" type="text/javascript">
#    </script>
#    <script src="../jqwidgets/jqwidgets/jqx-all.js" type="text/javascript">
#    </script>
#    <script src="../jqwidgets/jqwidgets/jqxcore.js" type="text/javascript">
#    </script>
#    <script src="../jqwidgets/jqwidgets/jqxdata.js" type="text/javascript">
#    </script>
#    <script src="../jqwidgets/jqwidgets/jqxbuttons.js" type="text/javascript">
#    </script>
#    <script src="../jqwidgets/jqwidgets/jqxscrollbar.js" type="text/javascript">
#    </script>
#    <script src="../jqwidgets/jqwidgets/jqxmenu.js" type="text/javascript">
#    </script>
#    <script src="../jqwidgets/jqwidgets/jqxcheckbox.js" type="text/javascript">
#    </script>
#    <script src="../jqwidgets/jqwidgets/jqxlistbox.js" type="text/javascript">
#    </script>
#    <script src="../jqwidgets/jqwidgets/jqxdropdownlist.js" type="text/javascript">
#    </script>
#    <script src="../jqwidgets/jqwidgets/jqxgrid.js" type="text/javascript">
#    </script>
#    <script src="../jqwidgets/jqwidgets/jqxgrid.sort.js" type="text/javascript">
#    </script>
#    <script src="../jqwidgets/jqwidgets/jqxgrid.pager.js" type="text/javascript">
#    </script>
#    <script src="../jqwidgets/jqwidgets/jqxgrid.selection.js" type="text/javascript">
#    </script>
#    <script src="../jqwidgets/jqwidgets/jqxgrid.columnsresize.js" type="text/javascript">
#    </script>
#    <script src="../jqwidgets/jqwidgets/jqxgrid.edit.js" type="text/javascript">
#    </script>
#    <script src="../jqwidgets/jqwidgets/jqxcombobox.js" type="text/javascript">
#    </script>
#    <script src="../jqwidgets/jqwidgets/jqxgrid.filter.js" type="text/javascript">
#    </script>
#    <script src="../jqwidgets/jqwidgets/jqxnotification.js" type="text/javascript">
#    </script>
#    <script src="../jqwidgets/jqwidgets/jqxgrid.grouping.js" type="text/javascript">
#    </script>
#    <script src="../jqwidgets/jqwidgets/jqxsplitter.js" type="text/javascript">
#    </script>
#    <script src="../jqwidgets/jqwidgets/globalization/globalize.js" type="text/javascript">
#    </script>
#    <script src="../jqwidgets/jqwidgets/globalization/globalize.culture.tw-TW.js" type="text/javascript">
#    </script>
#    <script src="../js/jquery-ui-1.10.4.custom/js/jquery-ui-1.10.4.custom.js" type="text/javascript">
#    </script>
#    <script src="../js/jquery-ui-1.10.4.custom/js/JQueryDatePickerTW.js" type="text/javascript">
#    </script>
#    <script src="../js/jquery-ui-1.10.4.custom/js/jquery.ui.datepicker-zh-TW.js" type="text/javascript">
#    </script>
#    <script src="../js/jquery.chained.min.js" type="text/javascript">
#    </script>
#    <script src="../js/jquery.chained.remote.min.js" type="text/javascript">
#    </script>
#    <script src="../js/lightbox.min.js">
#    </script>
#    <script src="../bower_components/bootstrap/dist/js/bootstrap.min.js" type="text/javascript">
#    </script>
#    <link href="../css/default.css" rel="stylesheet" type="text/css">
#     <link href="../jqwidgets/jqwidgets/styles/jqx.base.css" rel="stylesheet" type="text/css"/>
#     <link href="../js/jquery-ui-1.10.4.custom/css/base/jquery-ui-1.10.4.custom.min.css" rel="stylesheet" type="text/css"/>
#     <link href="../js/lightbox.css" rel="stylesheet">
#      <link href="../bower_components/bootstrap/dist/css/bootstrap.min.css" rel="stylesheet" type="text/css"/>
#      <link href="../js/jquery-file-upload/css/jquery.fileupload-ui.css" rel="stylesheet" type="text/css"/>
#      <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#      <meta content="-1" http-equiv="Expires">
#       <meta content="no-cache" http-equiv="pragma">
#        <meta content="no-cache" http-equiv="Cache-control">
#         <script src="/bower_components/bootstrap/dist/js/bootstrap.min.js;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz">
#         </script>
#         <script src="/bower_components/bootstrap-material-design/dist/js/ripples.min.js;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz">
#         </script>
#         <script src="/bower_components/bootstrap-material-design/dist/js/material.min.js;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz">
#         </script>
#         <script src="/bower_components/momentjs/min/moment.min.js;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz">
#         </script>
#         <script src="/bower_components/bootstrap-material-datetimepicker/js/bootstrap-material-datetimepicker.js;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz">
#         </script>
#         <script src="/bower_components/moment/min/moment-with-locales.min.js;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz" type="text/javascript">
#         </script>
#         <script src="/bower_components/eonasdan-bootstrap-datetimepicker/build/js/bootstrap-datetimepicker.min.js;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz" type="text/javascript">
#         </script>
#         <script src="/bower_components/sweetalert/dist/sweetalert.min.js;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz" type="text/javascript">
#         </script>
#         <script src="/bower_components/feedback/js/feedback.js;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz">
#         </script>
#         <script src="/js/jquery/jquery.blockUI.js;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz" type="text/javascript">
#         </script>
#         <link href="/bower_components/bootstrap/dist/css/bootstrap.min.css;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz" rel="stylesheet" type="text/css"/>
#         <link href="/bower_components/bootstrap-material-design/dist/css/roboto.min.css;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz" rel="stylesheet" type="text/css"/>
#         <link href="/bower_components/bootstrap-material-design/dist/css/material.min.css;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz" rel="stylesheet" type="text/css"/>
#         <link href="/bower_components/bootstrap-material-design/dist/css/ripples.min.css;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz" rel="stylesheet" type="text/css"/>
#         <link href="/bower_components/bootstrap-material-design/dist/css/custom.css;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz" rel="stylesheet" type="text/css"/>
#         <link href="/bower_components/bootstrap-material-datetimepicker/css/bootstrap-material-datetimepicker.css;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz" rel="stylesheet" type="text/css"/>
#         <link href="/bower_components/feedback/css/feedback.css;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz" rel="stylesheet" type="text/css"/>
#         <link href="/bower_components/eonasdan-bootstrap-datetimepicker/build/css/bootstrap-datetimepicker.min.css;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz" rel="stylesheet" type="text/css">
#          <link href="/bower_components/bootstrap-material-design/dist/css/fonts.css;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz?family=Roboto:400,500" rel="stylesheet" type="text/css"/>
#          <link href="/bower_components/bootstrap-material-design/dist/css/icon.css;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz?family=Material+Icons" rel="stylesheet" type="text/css"/>
#          <link href="/bower_components/sweetalert/dist/sweetalert.css;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz" rel="stylesheet" type="text/css"/>
#          <script src="/js/jquery.hoverpulse.js;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz" type="text/javascript">
#          </script>
#          <script src="/js/highcharts.js;jsessionid=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz" type="text/javascript">
#          </script>
#          <style type="text/css">
#           .field_markTitle{
# 	color: #FF0000;
# 	font-size: 20px;
# 	font-weight: bold;
# }
# #watermark{
# 	-moz-transform: rotate(-45deg);
# 	-webkit-transform: rotate(-45deg);
# 	-o-transform: rotate(-45deg);
# 	-ms-transform: rotate(-45deg);
# 	display: block;
# 	color: #c0c0c0;
# 	border: 1px solid olive;
# 	border-color: #c0c0c0;
# 	font-size: 30;
# 	position: absolute;
# 	right: 40%;
# 	top: 300;
# 	padding: 0px 40px;
# 	z-index: 1;
# }
# .scn_banner {
# 	height: 30px;
# 	min-width: 240px;
# 	margin: 0 auto;
# 	font-weight: bold;
# 	font-size: 15px;
# 	padding-left: 6px;
# 	background: #e1ffff; /* Old browsers */
# 	background: -moz-linear-gradient(top,  #e1ffff 0%, #e1ffff 7%, #e1ffff 12%, #fdffff 12%, #e6f8fd 30%, #c8eefb 54%, #bee4f8 75%, #b1d8f5 100%); /* FF3.6-15 */
# 	background: -webkit-linear-gradient(top,  #e1ffff 0%,#e1ffff 7%,#e1ffff 12%,#fdffff 12%,#e6f8fd 30%,#c8eefb 54%,#bee4f8 75%,#b1d8f5 100%); /* Chrome10-25,Safari5.1-6 */
# 	background: linear-gradient(to bottom,  #e1ffff 0%,#e1ffff 7%,#e1ffff 12%,#fdffff 12%,#e6f8fd 30%,#c8eefb 54%,#bee4f8 75%,#b1d8f5 100%); /* W3C, IE10+, FF16+, Chrome26+, Opera12+, Safari7+ */
# 	filter: progid:DXImageTransform.Microsoft.gradient( startColorstr='#e1ffff', endColorstr='#b1d8f5',GradientType=0 ); /* IE6-9 */
# 	-webkit-border-radius: 5px;
# 	-moz-border-radius: 5px;
# 	border-radius: 5px;
# 	text-align:left;
# 	white-space: nowrap;
# }
# .scn_banner:before {
# 	content: '';
# 	display: inline-block;
# 	vertical-align: middle;
# 	width: 0;
# 	height: 100%;
# }
# .scn_tdLabel {
# 	width:20%;
# 	text-align:right;
# 	white-space: nowrap;
# }
# .scn_tdText {
# 	width:80%;
# 	font-weight:bold;
# }
# .scn_tdText_Draft {
# 	color: #0000ff;
# }
# .item_border{
# 	margin-top:4px;
# 	margin-bottom:9px;
# 	-moz-box-shadow:3px 3px 9px 3px rgba(20%,20%,40%,0.5);
# 	-webkit-box-shadow:3px 3px 9px 3px rgba(20%,20%,40%,0.5);
# 	box-shadow:3px 3px 9px 3px rgba(20%,20%,40%,0.5);
# }
# .scn11_border{
# 	margin-top:5px;
# 	margin-bottom:5px;
# 	-moz-box-shadow:1px 1px 3px 1px rgba(20%,20%,40%,0.5);
# 	-webkit-box-shadow:1px 1px 3px 1px rgba(20%,20%,40%,0.5);
# 	box-shadow:1px 1px 3px 1px rgba(20%,20%,40%,0.5);
# }
# .btn_tool {
# 	margin: 2px;
# 	min-width:100px;
# 	padding: 5px 10px;
# 	font-size: 14px;
# 	line-height: 1.2;
# 	border-radius: 3px;
# 	white-space:normal;
# }
# .tooltip {
# 	width:135px;
# 	margin-left:50px;
#     text-align: left;
#     background-color: #000;
#     color: #fff;
#
# 	line-height:1.1;
# 	font-size: 14px;
# 	border-radius: 6px;
# }
# .tooltip-inner {
#     text-align: left;
#     background-color: #000;
# }
# .langHide_US {
# 	;
# }
# .langHide_TW {
# 	display:none !important;;
# }
# @media print {
# 	.noprint {display:none;}
# }
#          </style>
#         </link>
#        </meta>
#       </meta>
#      </meta>
#     </link>
#    </link>
#   </meta>
#  </head>
#  <body>
#   <script src="../js/commonUtils.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    window.open = function (open) {
#     return function (url, name, features, opentab) {
#         url = appendParam(url, 'l6', 'zh_TW');
#         url = appendParamIfAnnouncementRead(url);
#
#         features = features || [
#                       'height='+(screen.height - 50)
#                       ,'width='+(screen.width)
#                       ,'resizable=yes'
#                       ,'scrollbars=yes'
#                   ].join(',');
#         var popup;
#         if (opentab)
#             popup = open.call(window, url, name);
#         else
#         	popup = open.call(window, url, name, features);
#         popup.moveTo(0,0);
#     };
# }(window.open);
#
# $(document).ready(function() {
# 	$('#announcement-close-btn').click(function() {
# 		$('.announcement.well').hide();
# 	});
#
#
# 	var data432 = [{"CODE_ID":"en_US","CODE_NAME_C":"English","FLAG1":"-2","ID":1141,"FLAG2":"../OS0/OS0101.jsp"},{"CODE_ID":"zh_TW","CODE_NAME_C":"中文","FLAG1":"-1","ID":1140,"FLAG2":"../OS0/OS0101.jsp"}];
# 	//commonUtils.getDropDownMenuSelected(data432, 'l6', 'CODE_NAME_C', 'CODE_ID', 'zh_TW', 'Y');
# 	commonUtils.getLanguageText(data432, 'l8', 'CODE_NAME_C', 'CODE_ID', 'zh_TW', 'Y');
#
# 	$('#inAnnouncement').click(function() {
# 		inputAnnouncement();
# 		showModelForm('#complete-dialog');
# 	});
#
#
# 	$.material.init();
# 	$('.date').each(function(){
# 		$(this).datepickerEn();
# 	});
#
# 	$('.dateC').each(function(){
# 		$(this).datepickerTW();
# 	});
#
# 	$('a').click(function (event){
# 		var href = $(this).prop("href");
# 		if (!href) return true;
# 		if (href.indexOf("javascript:") == -1 && href.indexOf("OS0") > -1){
# 			href = appendParam(href, 'l6', 'zh_TW');
# 			href = appendParamIfAnnouncementRead(href);
# 		}
# 		$(this).prop("href", href);
# 	});
#
# 	$.ajax.global = true;
# 	$( document ).ajaxSend(function( event, jqxhr, settings ) {
# 		  var url = settings.url;
# 		  url = appendParamIfAnnouncementRead(url);
# 		  settings.url = appendParam(url, 'l6', 'zh_TW');
#
# 	});
#
# 	$( document ).submit(function( event ) {
# 		var jForm = $(event.target);
# 		var action = jForm.prop('action');
# 		if(!action){
# 			action = window.location.href;
# 		}
#
# 		action = appendParam(action, 'l6', 'zh_TW');
# 		action = appendParamIfAnnouncementRead(action);
# 		if ($('#lc').val())
# 			action = appendParam(action, 'lc', $('#lc').val());
#
# 		jForm.prop('action', action);
# 	});
# });
# function chgLanguage(xx){
# 	$('#lc').val( xx );
# 	$('#headerForm').submit();
# }
#
# function appendParam(url, key, value){
# 	if (url.indexOf("?") === -1)
# 		url = url + "?";
#
# 	var lastChar = url.substr(url.length - 1);
#
# 	if ( lastChar !== "?" && lastChar !== "&")
# 		url = url + "&";
#
# 	var param = {};
# 	param[key] = value;
# 	return url + jQuery.param(param) ;
# }
#
# function appendParamIfAnnouncementRead(url){
# 	url = appendParam(url, 'isReadBulletinen_US', '');
# 	url = appendParam(url, 'isReadBulletinzh_TW', 'true');
#
# 	return url;
# }
#
# function showModelForm(id) {
# 	$(id).modal('show');
# }
#   </script>
#   <form id="headerForm" style="height: 100%">
#    <div class="home-header header-panel shadow-z-2" style="height:86px;">
#     <div class="container">
#      <div class="row">
#       <table style="width:100%;">
#        <tr>
#         <td style="width:58%;">
#          <h1>
#          </h1>
#          <input id="lc" name="lc" type="hidden" value=""/>
#          <input id="isReadBulletinzh_TW" name="isReadBulletinzh_TW" type="hidden" value="true"/>
#          <input id="isReadBulletinen_US" name="isReadBulletinen_US" type="hidden" value=""/>
#         </td>
#         <td class="text-left" style="color:white;vertical-align:top;">
#          <p class="language">
#           <br/>
#           一般：109/09/21 前申請已領案
#           <br/>
#           快軌：109/11/20 前申請已領案
#          </p>
#         </td>
#         <td class="text-right" style="vertical-align:top;">
#          <p class="language">
#           Language:
#           <span id="l8">
#           </span>
#          </p>
#          <span class="data-update-time">
#           <img id="inAnnouncement" src="/images/i_tag.png"/>
#           資料更新時間：2021-04-11
#          </span>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </div>
#    </div>
#    <div class="announcement well">
#     <button class="close" data-dismiss="alert" id="announcement-close-btn" type="button">
#      ×
#     </button>
#     <div id="announcement-content">
#      <b>
#       <font size="3">
#        <font color="#ff00ff">
#         本系統請勿開啟「相容性檢視設定」，以確保顯示正常。
#        </font>
#       </font>
#      </b>
#      <br/>
#      <div>
#       <b>
#        <font size="3">
#         <font color="blue">
#          近期增修功能如下：
#         </font>
#        </font>
#       </b>
#      </div>
#      ◎單筆詳表「組群代碼」：若指定商品與現行「商標電子申請系統參考名稱」相同者，顯示對應英文名稱[109.10]
#      <br/>
#      ◎圖形近似檢索：增修英文版頁面[109.08]
#      <br/>
#      ◎商品分類查詢：增修切換「筆畫排序」、商品服務名稱的「匯出全類」功能
#      <br/>
#      ◎布林查詢：檢索條件上限增加為10組
#      <br/>
#      ◎單筆詳表：申請日於108.1.1後的申請案，顯示補正收文的內容主旨
#      <br/>
#      ◎結果頁　：詳表、簡表 點擊圖樣可另開報表；簡表顯示版面更新
#      <br/>
#      <br/>
#      商標新申請案自送件日至檢索系統可查到案件所需的天數：
#      <br/>
#      (1)採
#      <b>
#       <font color="#ff00ff">
#        線上申請
#       </font>
#      </b>
#      方式，約第 4 天可查到案件；因資料核對作業關係，請於提出申請次日約 14 個工作日後再行查詢。
#      <br/>
#      (2)採
#      <b>
#       <font color="#ff00ff">
#        紙本申請
#       </font>
#      </b>
#      方式，約第 10 天可查到案件；因資料建檔、核對作業關係，請於提出申請次日約 40 個工作日後再行查詢。
#      <br/>
#     </div>
#    </div>
#    <div class="modal fade" id="complete-dialog" tabindex="-1">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="modal-header">
#        <button aria-hidden="true" class="close" data-dismiss="modal" type="button">
#         ×
#        </button>
#        <h4 class="modal-title">
#         資料更新說明及公告
#        </h4>
#       </div>
#       <div class="modal-body">
#       </div>
#      </div>
#     </div>
#    </div>
#   </form>
#   <script type="text/javascript">
#   </script>
#   <form class="form-horizontal">
#    <input id="showType" name="showType" type="hidden" value="2"/>
#    <input id="caseType" name="caseType" type="hidden" value="1"/>
#    <input id="caseNo" name="caseNo" type="hidden" value=""/>
#    <input id="shit" name="shit" type="hidden" value="0"/>
#    <input id="caseNo2" name="caseNo2" type="hidden" value=""/>
#    <div style="display: none">
#     <div id="msg_nonInfo">
#      <label class="scn_tdLabel" style="color:#C0C0C0;">
#       （無相關資訊）
#      </label>
#     </div>
#     <span id="scn3_applDate">
#      申請日
#     </span>
#     <span id="scn3_finishDate">
#      辦結日期
#     </span>
#     <span id="scn3_rejNoticeDate">
#      核駁公告日期
#     </span>
#     <span id="scn3_appeal">
#      行政訴訟
#     </span>
#     <span id="scn3_examNoticeDate">
#      審定公告日期
#     </span>
#     <span id="scn3_oppDeadline">
#      異議期限
#     </span>
#     <span id="scn3_regNoticeDate">
#      註冊公告日
#     </span>
#     <span id="scn3_deadline">
#      專用期限
#     </span>
#     <span id="scn3_extendedDeadline">
#      延展期限
#     </span>
#     <span id="scn3_extendedLine">
#      延展中
#     </span>
#     <span id="scn3_oppLine">
#      爭議中
#     </span>
#     <span id="scn3_extendedApplDateLine">
#      延展申請起始日
#     </span>
#     <div id="scn12_none">
#      <label class="scn_tdLabel" style="color:#C0C0C0;">
#       （無）
#      </label>
#     </div>
#    </div>
#    <div class="container">
#     <div class="well">
#      <div class="row" id="SCN1">
#      </div>
#      <script id="templateSCN1" type="text/x-handlebars-template">
#       <input type="hidden" id="tableId" value="{{id}}">
# 	<input type="hidden" id="chSpecFileName" value="{{chSpecFileName}}">
# 	<input type="hidden" id="enSpecFileName" value="{{enSpecFileName}}">
# 	<input type="hidden" id="issueKey" value="{{issueKey}}">
# 	<div class="col-md-12 noprint" id="SCN1_btn" style="text-align:right;">
# 		{{#ifEq showType '1'}}
# 			<button id="doQuerySTM41" class="btn btn-success btn_tool" type="button">註冊費查詢</button>
# 		{{/ifEq}}
# 		{{#ifEq showType '2'}}
# 			{{#ifEq chSpecSta 'Y'}}
# 				<button id="downloadPDFChSpec" class="btn btn-success btn_tool" type="button">使用規範書</button>
# 			{{/ifEq}}
# 			{{#ifEq enSpecSta 'Y'}}
# 				<button id="downloadPDFEnSpec" class="btn btn-success btn_tool" type="button">使用規範書(外文)</button>
# 			{{/ifEq}}
# 			<button id="doQueryExamCaseInfo" class="btn btn-success btn_tool" type="button">註冊簿</button>
# 		{{/ifEq}}
# 		{{#ifEq showType '3'}}
# 			<button id="openPageXml" class="btn btn-success btn_tool" type="button">核駁處分書</button>
# 		{{/ifEq}}
# 		<button id="doPrint" class="btn btn-success btn_tool" type="button">列印</button>
# 		<button id="doPrintFriendly" class="btn btn-success btn_tool" type="button">報表列印</button>
# 		<button type="button" id="showHelper_Printing" class="btn btn-success btn_tool pull-right"><span class="btn_icon"></span>列印說明</button>
# 	</div>
#
# 	<div class="col-md-6" style="font-weight:bold;font-size:18px;">商標單筆詳細報表</div>
# 	<div class="col-md-6" style="font-weight:bold;font-size:12px;text-align:right;">本頁產生時間為：{{systemDate}}</div>
# 	<div class="col-md-12" style="">
# 		<span style="font-size:15px;font-weight:bold;">
# 			{{#ifEq showType '1'}}申請號{{/ifEq}}
# 			{{#ifEq showType '2'}}註冊/審定號{{/ifEq}}
# 			{{#ifEq showType '3'}}核駁號{{/ifEq}}
# 			{{#ifEq showType '4'}}其他應檢索之參考資料{{/ifEq}}
# 			：{{caseNo}}
# 		</span>
# 		{{#ifEq divideFlag 'Y'}}{{#if divideText}}(
# 			{{#ifnotEq showType '3'}}
# 				<span class="field_markTitle">已分割</span>
# 				{{#each divideText}}
# 					{{#ifnotEq @index 0}}, {{/ifnotEq}}
# 					<a href="javascript:gotoSS0201('{{../showType}}','{{caseNoEnc}}','','{{caseType}}');">{{caseNo_pfxText}}{{caseNo}}</a>
# 				{{/each}}
# 				<div id="watermark">本案已分割</div>
# 			{{else}}
# 				<span class="field_markTitle">撤銷另審</span>
# 				申請號<a href="javascript:gotoSS0201('1','{{divideText_enc}}','','');">{{divideText}}</a>
# 			{{/ifnotEq}}
# 		){{/if}}{{/ifEq}}
# 		{{#ifnotEq divideFlag 'Y'}}{{#if oldCaseNo}}(
# 			<span class="field_markTitle">分割前</span>
# 			<a href="javascript:gotoSS0201('1','{{oldCaseNoEnc}}','','');">{{oldCaseNo}}</a>
# 		){{/if}}{{/ifnotEq}}
# 		{{#ifEq abateFlag 'Y'}}{{#if abateText}}
# 			 (<span class="field_markTitle">{{abateText}}</span>)
# 		{{/if}}{{/ifEq}}
# 		{{#ifEq delFlag 'Y'}}{{#if delText}}
# 			 (<span class="field_markTitle">{{delText}}</span>)
# 		{{/if}}{{/ifEq}}
# 		{{#ifEq fastTrack 'Y'}}
# 			 (<span class="field_markTitle">快軌案</span>)
# 		{{/ifEq}}
# 	</div>
# 	<div id="helper-dialog" class="modal fade" tabindex="-1">
# 		<div class="modal-dialog" style="width:700px">
# 			<div class="modal-content">
# 				<div class="modal-header">
# 					<button type="button" class="close" data-dismiss="modal" aria-hidden="true">×</button>
# 					<h4 class="modal-title">小幫手</h4>
# 				</div>
# 				<br/>
# 				<div class="modal-body">
# 					<p><font color="red">Hello </font>你好！</p>
# 				</div>
# 				<div class="modal-footer">
# 					<button class="btn btn-primary" data-dismiss="modal">關閉</button>
# 				</div>
# 		    </div>
# 	    </div>
#     </div>
#      </script>
#      <script type="text/javascript">
#       function doSCN1(datas){
# 	var template = Handlebars.compile($("#templateSCN1").html());
# 	$("#SCN1").html(template(datas));
#
# 	$("#doQuerySTM41").on('click', function(){
# 		window.open(getVirtualPath()+"OS0/OS0305_SCN1.jsp?applNo_0="+$("#caseNo").val(),"_blank","","Y");
# 	});
# 	$("#doQueryExamCaseInfo").on('click', function(){
# 		var q = "1&state=print&tmarkClass="+$("#caseType").val()+"&examNo="+$("#caseNo").val();
# 		window.open(getVirtualPath() + "SS0/SS0204_q.jsp?="+decodeURIComponent(q),"_blank","","Y");
#
# 	});
# 	$("#downloadPDFChSpec").on('click', function(){
# 		window.open(getVirtualPath()+"download.jsp?path="+$("#chSpecFileName").val()+"&pathCodeId=282_SPEC", "_top");
# 	});
# 	$("#downloadPDFEnSpec").on('click', function(){
# 		window.open(getVirtualPath()+"download.jsp?path="+$("#enSpecFileName").val()+"&pathCodeId=282_SPEC", "_top");
# 	});
# 	$("#openPageXml").on('click', function(){
# 		if ($("#issueKey").val() == '') return;
# 		popOS0401($("#issueKey").val());
# 	});
# 	$("#doPrint").on('click', function(){
# 		window.print();
# 	});
# 	$("#doPrintFriendly").on('click', function(){
# 		var q = 'showType='+$('#showType').val()+'&caseType='+$('#caseType').val()+'&caseNo='+$('#caseNo').val()+'&caseNo2='+$('#caseNo2').val();
# 		var url = './friendlyPrinting.jsp?' + decodeURIComponent(q);
# 		window.open(url, "_blank", "", "Y");
# 	});
#
# 	$("#showHelper_Printing").on('click', function() {
# 		inputHelperContent('SS0201.S1.PRT' + '.1', '#helper-dialog', 'zh_TW');
# 	});
# }
#      </script>
#      <div class="row" id="SCN2">
#      </div>
#      <style type="text/css">
#       .scn2label{
# 	width:20%;
# 	text-align:right;
# 	white-space: nowrap;
# }
# .scn2text{
# 	width:22%;
# 	font-weight:bold;
# }
#      </style>
#      <script id="templateSCN2" type="text/x-handlebars-template">
#       <table style="width:100%;">
# 	<tr>
# 		<td class="scn2label">商標名稱：</td>
# 		<td colspan="3" class="scn2text">{{tmarkName}}</td>
# 		<td width="20%" rowspan="8" valign="top">
# 			{{#if tmarkColor}}  (  {{tmarkColor}}  )  {{/if}}
# 			{{#if tmarkType}}  (  {{tmarkType}}  )  {{/if}}
# 			{{#if fullAudioFileName}}
# 				<button type="button" style="width:30px;display:none;" onclick="<!--{{fullAudioFileName}}-->"><span class="mdi-av-video-collection" style="font-size: 16px;"></span></button>
# 			{{/if}}
# 			<div id="thumb">
# 				<img class="item_border" style="position: absolute;z-index: 2;width: 110px; height: 110px;margin-right:10px;"
# 					src="../imageLoad.jsp?path={{fullFileName}}&formatName=jpeg&pathCodeId={{#ifEq showType '4'}}282_pic_non{{else}}282_pic{{/ifEq}}">
# 			</div>
# 		</td>
# 	</tr>
# 	{{#ifnotEq showType '4'}}
# 		<tr>
# 			<td class="scn2label">申請案號：</td>
# 			<td class="scn2text">{{applNo}}</td>
# 			<td class="scn2label">申請日期：</td>
# 			<td class="scn2text">{{applDate}}</td>
# 		</tr>
# 		{{#ifEq showType '2'}}
# 			<tr>
# 				<td class="scn2label">註冊/審定號：</td>
# 				<td class="scn2text">{{examNo}}</td>
# 				<td class="scn2label">正註冊/審定號：</td>
# 				<td class="scn2text">{{rightExamNo}}</td>
# 			</tr>
# 			<tr>
# 				<td class="scn2label">審定公告日期(卷期)：</td>
# 				<td class="scn2text">{{examNoticeDate}}{{examNoticeDateVolNo}}</td>
# 				<td class="scn2label">註冊日期：</td>
# 				<td class="scn2text">{{regDate}}</td>
# 			</tr>
# 			<tr >
# 				<td class="scn2label">註冊公告日期(卷期)：</td>
# 				<td class="scn2text">{{regNoticeDate}}{{regNoticeDateVolNo}}</td>
# 				<td class="scn2label">專用期限：</td>
# 				<td class="scn2text">{{deadLine}}</td>
# 			</tr>
# 		{{/ifEq}}
# 		{{#ifEq showType '3'}}
# 			<tr>
# 				<td class="scn2label">核駁號：</td>
# 				<td class="scn2text">{{rejExamNo}}</td>
# 				<td class="scn2label">核駁公告日期(卷期)：</td>
# 				<td class="scn2text">{{regNoticeDate}}{{regNoticeDateVolNo}}</td>
# 			</tr>
# 			<tr>
# 				<td class="scn2label">行政救濟紀錄：</td>
# 				<td class="scn2text">{{appealMark}}</td>
# 				<td class="scn2label">決定/判決結果：</td>
# 				<td class="scn2text">{{showFlagName}}</td>
# 			</tr>
# 		{{/ifEq}}
# 		<tr>
# 			<td class="scn2label">商品類別：</td>
# 			<td colspan="3" class="scn2text">{{goodsClasses}}</td>
# 		</tr>
# 	{{else}}
# 		<tr>
# 			<td class="scn2label">號數：</td>
# 			<td class="scn2text">{{nonNo}}</td>
# 			<td class="scn2label">有效日期：</td>
# 			<td class="scn2text">{{deadline}}</td>
# 		</tr>
# 		<tr>
# 			<td class="scn2label">公告日：</td>
# 			<td colspan="3" class="scn2text">{{noticeDate}}</td>
# 		</tr>
# 		<tr>
# 			<td class="scn2label">資料來源：</td>
# 			<td colspan="3" class="scn2text">{{dataSource}}</td>
# 		</tr>
# 	{{/ifnotEq}}
# </table>
#      </script>
#      <script type="text/javascript">
#       function doSCN2(datas){
# 	datas.SCN2.showType = datas.showType;
# 	var template = Handlebars.compile($("#templateSCN2").html());
# 	$("#SCN2").html(template(datas.SCN2));
#     $('#thumb img').hoverpulse({
#         size: 70,
#         speed: 400
#     });
# }
#      </script>
#      <div class="row" id="SCN3" style="display:none;">
#       <div class="col-md-12">
#        <button class="scn_banner" id="SCN3_diagram_banner" type="button">
#         案件時序圖(TimeLine)
#        </button>
#       </div>
#       <div class="col-md-12">
#        <div id="SCN3_diagram" style="margin: 0 auto;">
#        </div>
#       </div>
#      </div>
#      <div class="row noprint" id="SCN0">
#       <div class="col-md-12">
#        <button class="btn btn-info btn-raised btn_tool" onclick="showSCN(true);" type="button">
#         展開
#        </button>
#        <button class="btn btn-info btn-raised btn_tool" onclick="showSCN(false);" type="button">
#         收合
#        </button>
#       </div>
#      </div>
#      <div class="row" id="SCN4" style="display:none;">
#       <div class="col-md-12">
#        <button class="scn_banner" type="button">
#         優先權
#        </button>
#       </div>
#       <div class="col-md-12" id="SCN4_detail" style="display:block;">
#       </div>
#       <script id="templateSCN4" type="text/x-handlebars-template">
#        <table width="100%">
# 						{{#if applDateText}}
# 							<tr>
# 								<td class="scn_tdLabel">優先權：</td>
# 								<td class="scn_tdText">{{applDateText}}</td>
# 							</tr>
# 						{{/if}}
# 						{{#if applRemarkText}}
# 							<tr>
# 								<td class="scn_tdLabel">展覽優先權：</td>
# 								<td class="scn_tdText">{{applRemarkText}}</td>
# 							</tr>
# 						{{/if}}
# 					</table>
#       </script>
#      </div>
#      <div class="row" id="SCN5" style="display:none;">
#       <div class="col-md-12">
#        <button class="scn_banner" id="SCN5_titleName" type="button">
#        </button>
#        <span id="scn5_title1" style="display:none;">
#         申請人
#        </span>
#        <span id="scn5_title2" style="display:none;">
#         商標權人
#        </span>
#        <span id="scn5_title3" style="display:none;">
#         標章權人
#        </span>
#        <script>
#         var titleName = ($("#showType").val() == "1") ? $("#scn5_title1").text() :
# 											($("#showType").val() == "2") ? ( ($("#caseType").val() == "7" || $("#caseType").val() == "8") ? $("#scn5_title3").text() : $("#scn5_title2").text()) :
# 											($("#showType").val() == "3") ? $("#scn5_title1").text() :
# 											"所有人";
# 							$("#SCN5_titleName").html(titleName);
#        </script>
#       </div>
#       <div class="col-md-12" id="SCN5_detail" style="display:block;">
#       </div>
#       <script id="templateSCN5" type="text/x-handlebars-template">
#        {{#each list}}
# 						{{#ifnotEq @index 0}}<br>{{/ifnotEq}}
# 						<table width="100%">
# 							<tr>
# 								<td class="scn_tdLabel">中文名稱：</td>
# 								<td class="scn_tdText">{{nameC}}</td>
# 							</tr>
# 							{{#if nameE}}
# 								<tr>
# 									<td class="scn_tdLabel">英文名稱：</td>
# 									<td class="scn_tdText">{{nameE}}</td>
# 								</tr>
# 							{{/if}}
# 							<tr>
# 								<td class="scn_tdLabel">中文地址：</td>
# 								<td class="scn_tdText">{{addrC}}</td>
# 							</tr>
#
# 						</table>
# 					{{/each}}
#       </script>
#      </div>
#      <div class="row" id="SCN6" style="display:none;">
#       <div class="col-md-12">
#        <button class="scn_banner" id="SCN6_titleName" type="button">
#         代理人
#        </button>
#       </div>
#       <div class="col-md-12" id="SCN6_detail" style="display:block;">
#       </div>
#      </div>
#      <div class="row" id="SCN7" style="display:none;">
#       <div class="col-md-12">
#        <button class="scn_banner" type="button">
#         商品類別與商品(服務)名稱
#        </button>
#       </div>
#       <div class="col-md-12" id="SCN7_detail" style="display:block;">
#       </div>
#       <script id="templateSCN7" type="text/x-handlebars-template">
#        <button id="SCN7_goodsGroup" class="btn btn-info btn-raised btn_tool noprint" type="button">組群代碼</button>
# 					<button id="SCN7_1_goodsGroup" class="btn btn-info btn-raised btn_tool noprint" type="button">商品組群單(組群)</button>
# 					{{#each list}}
# 						<table width="100%">
# 							{{#ifnotEq @index 0}}<tr><br/></tr>{{/ifnotEq}}
# 							<tr>
# 								<td style="width:15%;text-align:center;"style="font-weight:bold;">
# 									{{goodsClass}}
# 									{{#if goodsGroup}}
# 										<br><img src="../images/plus_icon.gif" height="15px" width="15px" onClick="showSCN7Item(this, true);">
# 										<img src="../images/minus_icon.gif" height="15px" width="15px" style="display:none;" onClick="showSCN7Item(this, false);">
# 									{{/if}}
# 								</td>
# 								<td style="width:85%;">{{classGoodsName}}</td>
# 							</tr>
# 							{{#if goodsGroup}}
# 								<tr style="display:none;">
# 									<td style="text-align:center;">類似組群</td>
# 									<td>{{goodsGroup}}</td>
# 								</tr>
# 							{{/if}}
# 						</table>
# 					{{/each}}
#       </script>
#      </div>
#      <div class="row" id="SCN8" style="display:none;">
#       <div class="col-md-12">
#        <button class="scn_banner" type="button">
#         加註事項
#        </button>
#       </div>
#       <div class="col-md-12" id="SCN8_detail" style="display:block;">
#       </div>
#       <script id="templateSCN8" type="text/x-handlebars-template">
#        <table width="100%">
# 						{{#if outOffDraft}}
# 							<tr>
# 								<td class="scn_tdLabel">聲明不專用：</td>
# 								<td class="scn_tdText">{{outOffDraft}}</td>
# 							</tr>
# 						{{/if}}
# 						{{#if tmarkDesc}}
# 							<tr>
# 								<td class="scn_tdLabel">商標圖樣描述：</td>
# 								<td class="scn_tdText">{{tmarkDesc}}</td>
# 							</tr>
# 						{{/if}}
# 						{{#if describeText}}
# 							<tr>
# 								<td class="scn_tdLabel">說明文字內容：</td>
# 								<td class="scn_tdText">{{describeText}}</td>
# 							</tr>
# 						{{/if}}
# 						{{#if remarkText}}
# 							<tr>
# 								<td class="scn_tdLabel">備註：</td>
# 								<td class="scn_tdText">{{remarkText}}</td>
# 							</tr>
# 						{{/if}}
# 					</table>
#       </script>
#      </div>
#      <div class="row" id="SCN9" style="display:none;">
#       <div class="col-md-12">
#        <button class="scn_banner" type="button">
#         案件歷史(一般收文)
#        </button>
#       </div>
#       <div class="col-md-offset-1 col-md-10" id="SCN9_detail" style="display:block;">
#       </div>
#       <script id="templateSCN9" type="text/x-handlebars-template">
#        <table style="width:100%;" border="1">
# 						<tr align="center">
# 							<td>收(發)文日期</td>
# 							<td>收(發)文文號</td>
# 							<td>案號</td>
# 							<td>案由/事由</td>
# 							<td>辦理結果</td>
# 							<td>辦結日期</td>
# 							<td style="width:9%;">承辦人</td>
# 							<td style="width:90px;">
# 								{{#ifEq pType 'SCN9'}}備註{{/ifEq}}
# 							</td>
# 						</tr>
# 						{{sortSCN9 list}}
# 						{{#each list}}
# 							<tr align="center">
# 								<td>{{docDate}}</td>
# 								<td>{{docNo}}</td>
# 								<td>{{approNo}}</td>
# 								<td>{{reason}}</td>
# 								<td>{{resultProcess}}</td>
# 								<td>{{finishDate}}</td>
# 								<td>{{oppProcName}}</td>
# 								<td>
# 									{{#if issueKey}}
# 										<a class="btn btn-success btn_tool btn_text_none" href="javascript:popOS0401('{{issueKey}}');">
#
# 												{{#if issueBtnName}}{{issueBtnName}}{{else}}處分書{{/if}}
#
# 										</a>
# 									{{else}}
# 										{{#if correctItem}}
# 											{{safeStr correctItem}}
# 										{{/if}}
# 									{{/if}}
# 								</td>
# 							</tr>
# 						{{/each}}
# 					</table>
#       </script>
#      </div>
#      <div class="row" id="SCN10" style="display:none;">
#       <div class="col-md-12">
#        <button class="scn_banner" type="button">
#         案件歷史(爭議/行政救濟)
#        </button>
#       </div>
#       <div class="col-md-offset-1 col-md-10" id="SCN10_detail" style="display:block;">
#       </div>
#      </div>
#      <div class="row langHide_US" id="SCN11" style="display:none;">
#       <div class="col-md-12">
#        <button class="scn_banner" type="button">
#         案件關係
#        </button>
#       </div>
#       <div class="col-md-12" id="SCN11_detail" style="display:block;width:100%;margin: 0 auto;">
#        <div class="col-md-offset-1 col-md-10 scn11_border" id="SCN11_diagram">
#        </div>
#       </div>
#      </div>
#      <div class="row" id="SCN12" style="display:none;">
#       <div class="col-md-12">
#        <button class="scn_banner" type="button">
#         目前在案狀況
#        </button>
#       </div>
#       <div class="col-md-offset-1 col-md-6" id="SCN12_detail" style="display:block;">
#       </div>
#       <script id="templateSCN12" type="text/x-handlebars-template">
#        {{#each list}}
# 						<div class="col-sm-3">{{statusText}}</div>
# 					{{/each}}
#       </script>
#      </div>
#      <div class="row" id="SCN13" style="display:none;">
#       <div class="col-md-12">
#        <button class="scn_banner" type="button">
#         商標圖樣
#        </button>
#       </div>
#       <div class="col-md-12" id="SCN13_detail" style="display:block;">
#       </div>
#       <script id="templateSCN13" type="text/x-handlebars-template">
#        {{#each list}}
# 						{{#ifEq sort_id '7'}}
# 							<div class="col-sm-12">
# 								<a href="../download.jsp?path={{path}}&pathCodeId={{#ifEq ../showType '4'}}282_pic_non{{else}}282_pic{{/ifEq}}">影音檔下載</a>
# 							</div>
# 						{{/ifEq}}
# 					{{/each}}
# 					{{#each list}}
# 						{{#ifnotEq sort_id '7'}}
# 							<div class="col-sm-6" style="float: float;">
# 								圖{{serial @index}}<br>
# 								<div style="width: 280px; height: 280px;">
# 									<img style="width: 100%;height: 100%;" src="../imageLoad.jsp?path={{path}}&formatName=jpeg&pathCodeId={{#ifEq ../showType '4'}}282_pic_non{{else}}282_pic{{/ifEq}}">
# 								</div>
# 							</div>
# 						{{/ifnotEq}}
# 					{{/each}}
#       </script>
#      </div>
#      <div class="row" id="SCN14" style="display:none;">
#       <div class="col-md-12">
#        <button class="scn_banner" id="SCN14_titleName" type="button">
#         圖樣文字分析
#        </button>
#        <span id="scn14_title2" style="display:none;">
#         被核駁圖樣文字分析
#        </span>
#        <script>
#         if($("#showType").val() == "3") $("#SCN14_titleName").text($("#scn14_title2").text());
#        </script>
#       </div>
#       <div class="col-md-12" id="SCN14_detail" style="display:block;">
#       </div>
#       <script id="templateSCN14" type="text/x-handlebars-template">
#        <table width="100%">
# 						{{#ifEq showType '3'}}
# 							<tr>
# 								<td class="scn_tdLabel">圖形核駁：</td>
# 								<td class="scn_tdText scn_tdText_Draft">{{#ifEq this.TMARK_FLAT '1'}}Y{{/ifEq}}</td>
# 							</tr>
# 							<tr>
# 								<td class="scn_tdLabel">被核駁圖樣中文：</td>
# 								<td class="scn_tdText scn_tdText_Draft">{{TMARK_DRAFT_C}}</td>
# 							</tr>
# 							<tr>
# 								<td class="scn_tdLabel">被核駁圖樣英文：</td>
# 								<td class="scn_tdText scn_tdText_Draft">{{TMARK_DRAFT_E}}</td>
# 							</tr>
# 							<tr>
# 								<td class="scn_tdLabel">被核駁圖樣日文：</td>
# 								<td class="scn_tdText scn_tdText_Draft">{{TMARK_DRAFT_J}}</td>
# 							</tr>
# 							<tr>
# 								<td class="scn_tdLabel">被核駁圖樣記號：</td>
# 								<td class="scn_tdText scn_tdText_Draft">{{TMARK_SIGN}}</td>
# 							</tr>
# 						{{else}}
# 							<tr>
# 								<td class="scn_tdLabel">圖樣中文：</td>
# 								<td class="scn_tdText scn_tdText_Draft">{{TMARK_DRAFT_C}}</td>
# 							</tr>
# 							<tr>
# 								<td class="scn_tdLabel">圖樣英文：</td>
# 								<td class="scn_tdText scn_tdText_Draft">{{TMARK_DRAFT_E}}</td>
# 							</tr>
# 							<tr>
# 								<td class="scn_tdLabel">圖樣日文：</td>
# 								<td class="scn_tdText scn_tdText_Draft">{{TMARK_DRAFT_J}}</td>
# 							</tr>
# 							<tr>
# 								<td class="scn_tdLabel">圖樣記號：</td>
# 								<td class="scn_tdText scn_tdText_Draft">{{TMARK_SIGN}}</td>
# 							</tr>
# 						{{/ifEq}}
# 					</table>
#       </script>
#      </div>
#      <div class="row" id="SCN15" style="display:none;">
#       <div class="col-md-12">
#        <button class="scn_banner" type="button">
#         核駁條款及據以核駁號
#        </button>
#       </div>
#       <div class="col-md-12" id="SCN15_detail" style="display:block;">
#       </div>
#       <script id="templateSCN15" type="text/x-handlebars-template">
#        <table style="width:100%;">
# 						<tr>
# 							<td class="scn_tdLabel">核駁條款：</td>
# 							<td class="scn_tdText">{{clauseText}}</td>
# 						</tr>
# 						<tr>
# 							<td class="scn_tdLabel">據以核駁號：</td>
# 							<td class="scn_tdText">
# 								{{#each examNoList}}
# 									{{#ifnotEq @index 0}}、{{/ifnotEq}}
# 									<a href="javascript:popupSS0201('2', '{{exam_no_enc}}', '', '{{tmark_class}}');">{{tmark_class_text}}</a>
# 								{{/each}}
# 							</td>
# 						</tr>
# 					</table>
#       </script>
#      </div>
#      <div class="row" id="SCN16" style="margin-top:20px;">
#       <div class="col-md-12" style="font-size: 15px; font-weight: bold;">
#        說明：
#        <br/>
#        本電腦查詢報表所示資料，為目前辦理狀態，僅供參考，不得作為申請案准駁、權利異動及侵害他人權益與否之依據，各項權利異動狀態，仍請洽本局相關單位確認。
#       </div>
#      </div>
#     </div>
#    </div>
#   </form>
#   <footer class="footer-distributed">
#    <div class="footer-left">
#     <p class="footer-links">
#      <a href="#">
#       智慧財產局版權所有
#      </a>
#      <img src="/images/copyright.png"/>
#      <span class="right">
#       最佳瀏覽器建議IE11以上解析度 1024 x 768
#      </span>
#      <br/>
#      <a href="#">
#       地址：台北市辛亥路二段185號3樓
#      </a>
#      <a href="#">
#       資料服務組服務台：(02)23767164、(02)23767165、(02)23767166
#      </a>
#      <span class="text-right">
#       來訪人數：00041216131
#      </span>
#     </p>
#    </div>
#   </footer>
#   <script type="text/javascript">
#    Handlebars.registerHelper({
# 	ifEq: function(v1, v2, opts) {
# 		return (v1 == v2) ? opts.fn(this) : opts.inverse(this);
# 	},
# 	ifnotEq: function(v1, v2, opts) {
# 		return (v1 != v2) ? opts.fn(this) : opts.inverse(this);
# 	},
# 	serial: function(index) {
# 		return index+1;
# 	},
# 	sortSCN9: function(list) {
#
# 		list = list.sort(function(a, b){return (a.docDate < b.docDate ||
# 				(a.docDate == b.docDate && a.docNo <= b.docNo)) ? 1 : -1;} );
# 	},
# 	safeStr: function(text) {
# 		return new Handlebars.SafeString(text);
# 	}
# });
#
# var scnShow = [];
# var timeVal = {x: 90, y:75, sizeW:1000, sizeH:220, imgW:75, imgH:75, levelH:75}, tLineW=700;
# var relVal = {x:300, y:60, sizeW:700, sizeH:150, imgW:50, imgH:50, levelH:80}, rLineW=200;
# $(document).ready(function() {
# 	doQuery();
# });
#
# function bindOnClick(){
# 	$("#SCN7_goodsGroup").on('click', function() {
# 		var caseItemType = {1:'41',2:'71',3:'44',4:''};
# 		var url = getVirtualPath() + "SS0/SS0203.jsp?tid="+$("#tableId").val()+"&fromtable="+caseItemType[$("#showType").val()];
# 		myWindow = window.open(url, "_blank", "scrollbars=yes,toolbar=no,resizable=yes,menubar=no,width=1020,height=795");
# 	});
# 	$("#SCN7_1_goodsGroup").on('click', function() {
# 		var caseItemType = {1:'41',2:'71',3:'44',4:''};
# 		var url = getVirtualPath() + "SS0/SS0203Sortable.jsp?tid="+$("#tableId").val()+"&fromtable="+caseItemType[$("#showType").val()];
# 		myWindow = window.open(url, "_blank", "scrollbars=yes,toolbar=no,resizable=yes,menubar=no,width=1020,height=795");
# 	});
# 	$(".scn_banner").on('click', function() {
# 		$(this).parent().parent().find("[id$='_detail']").toggle();
# 	});
# 	$("#SCN3_diagram_banner").on('click', function() {
# 		$('#SCN3_diagram').toggle();
# 	});
# }
#
# function doQuery(){
#
# 	lockUI(1, function (){
# 		$.ajax({
# 		  	type: "POST",
# 		  	url: getVirtualPath() + 'SS0/SS0201_q.jsp'+'?q=1&state=doQuery&showType='+$("#showType").val()+"&caseType="+$("#caseType").val()+"&caseNo="+$("#caseNo").val()+"&caseNo2="+$("#caseNo2").val(),
# 		  	dataType: 'json',
# 		  	async: true,
# 		  	timeout: 120000,
# 		  	success: function(json) {
# 		  		unLockUI();
# 				if(json.msg != ""){
# 					sweetAlert(json.msg);
# 					return;
# 				}
# 				var datas = json.datas;
# 				datas.showType = $("#showType").val();
# 				doSCN1(datas);
# 				doSCN2(datas);
# 				doSCN3(datas);
# 				doSCN11(datas);
# 				var scnList = ["SCN4", "SCN5", "SCN6", "SCN7", "SCN8", "SCN9", "SCN10", "SCN12", "SCN13", "SCN14", "SCN15"];
# 				for(var i=0;i<scnList.length;i++)
# 					doSCN(datas, scnList[i]);
# 				bindOnClick();
# 		  	},
# 			error: function (err) {
# 				unLockUI();
#
# 				sweetAlert("查詢發生異常！");
#
# 			}
# 		});
# 	});
# }
#
#
# function doSCN(datas, scnID) {
# 	if (datas[scnID+"_cnt"] > 0) return;
# 	if (!datas[scnID] && (scnID == "SCN8" || scnID == "SCN10")) return;
# 	var data = datas[scnID];
# 	if (data) {
# 		if(data instanceof Array)
# 			data = {showType:datas.showType, list:data};
# 		else
# 			data["showType"] = datas.showType;
# 		data["scnID"] = scnID;
# 		var tplID = (scnID == "SCN6") ? "SCN5" :
# 					(scnID == "SCN10") ? "SCN9" : scnID;
# 		var template = Handlebars.compile($("#template"+tplID).html());
# 		$("#"+scnID+"_detail").html(template(data));
# 	} else {
# 		var html = (scnID == "SCN12") ? $("#scn12_none").html():$("#msg_nonInfo").html();
# 		$("#"+scnID+"_detail").html(html);
# 	}
# 	scnShow.push(scnID+"_detail");
# 	$("#"+scnID).show();
# }
#
# function doSCN3(datas){
# 	var data = datas.SCN3;
# 	testSCN3(data);
# 	if(data && data.timingType != "0"){
# 		if(datas.showType == "1" || datas.showType == "3"){
# 			doTimeDiagram1(data.timingType, data);
# 		}else if(datas.showType == "2"){
# 			doTimeDiagram2(data.timingType, data);
# 		}
# 		$("#SCN3_diagram").height(timeVal.sizeH).width(timeVal.sizeW);
# 	}
# }
#
# function popOS0401(issueKey){
# 	var newwin = window.open(getVirtualPath() + "OS0/OS0401_SCN3.jsp?issueNo="+issueKey,"_blank","","Y");
# 	if (window.focus) {newwin.focus();}
# }
# function doSCN11(datas){
# 	var data = datas.SCN11;
# 	if (!data) return;
# 	doRealtionDiagram(data);
# 	$("#SCN11").show();
# 	scnShow.push("SCN11_detail");
# 	if (false){
# 		scrollTo_SCN("SCN11");
# 	}
# }
# function doRealtionDiagram(data) {
# 	var chartTop = (data.childList && data.childList.length > 1) ? (data.childList.length - 1) * relVal.levelH : 0;
# 	var chartBottom = (data.otherList && data.otherList.length > 0) ? (data.otherList.length) * relVal.levelH : 0;
# 	relVal.y += chartTop;
# 	relVal.sizeH += chartTop+chartBottom;
# 	$("#SCN11_diagram").highcharts({
#         chart: {
# 			width: relVal.sizeW,
# 			height: relVal.sizeH,
# 			backgroundColor: 'white',
#             events: {
#                 load: function () {
#                     var ren = this.renderer;
#                     if (data.case_no_text){
#                     	drawRelUnit(ren, "caseNow.png",data.case_no_text,"",0,0,1);
#                     }
#                     var caseParent={};
#                     if (data.parentDivide_caseNo_text){
#                     	caseParent.imgPath="caseParentDivide.png";
#                     	caseParent.lblStr = '<a href=\'javascript:gotoSS0201_SCN11("'+$("#showType").val()+'","'+data.parentDivide_caseNo_enc+'",null,"'+data.parentDivide_tmarkClass+'")\'>'
# 		                    					+ data.parentDivide_caseNo_text
# 		                    				+'</a>';
#                     	caseParent.tooltipHtml = data.parentDivide_applDate+''+data.parentDivide_divideDate;
#                     } else if (data.parentRej_caseNo_text){
#                     	caseParent.imgPath="caseParentRej.png";
#                     	caseParent.lblStr = '<a href=\'javascript:gotoSS0201_SCN11("3","'+data.parentRej_caseNo_text_enc+'","'+data.parentRej_caseNo2_text_enc+'",null)\'>'
# 						    					+ data.parentRej_caseNo_text
# 						    				+'</a>';
# 	                }
#                     if (caseParent.imgPath){
#                     	drawRelUnit(ren, caseParent.imgPath, caseParent.lblStr, "", -rLineW, 0, 1, caseParent.tooltipHtml);
#                     	drawRelPath(ren, -rLineW+relVal.imgW/2,0, -relVal.imgW/2,0, true, false);
#                     }
#
#                     if (data.childList) {
#                     	var pxE = rLineW, pyE = 0;
#                     	$.each(data.childList, function(i, obj){
#                     		var lblStr = '<a href=\'javascript:gotoSS0201_SCN11("'+obj.showType+'","'+obj.caseNo_enc+'",null,"'+obj.caseType+'")\'>'
# 				        					+ obj.caseNo_text
# 				            			+'</a>';
#                     		drawRelUnit(ren, "caseChild.png", lblStr, "", pxE, pyE, 2);
#                         	drawRelPath(ren, relVal.imgW/2,0, pxE-relVal.imgW/2, pyE, true, (i>0));
#                         	pyE -= relVal.levelH;
#                     	});
#                     }
#                     if (data.otherList) {
#                    		var pxE = rLineW/2, pyE = relVal.levelH;
#                     	$.each(data.otherList, function(i, obj){
#                     		var lblStr = (obj.appro_no) ? (obj.receiveDate_text?obj.receiveDate_text:'')+'<br>爭議號：'+obj.caseNo_text :
# 			                    		'<a href=\'javascript:gotoSS0201_SCN11("2","'+obj.caseNo_enc+'",null,"'+obj.caseType+'")\'>'
# 				        					+ obj.caseNo_text
# 				            			+'</a>';
#                     		drawRelUnit(ren, "caseOther.png", lblStr, "", pxE, pyE, 2);
#                         	drawRelPath(ren, 0,relVal.imgH/2, pxE-relVal.imgW/2, pyE, false, true);
#                         	pyE += relVal.levelH;
#                     	});
#                     }
#                 }
#             }
#         },
#         title: {
#             text: ''
#         }
#     });
# 	$("#SCN11_diagram").height(relVal.sizeH).width(relVal.sizeW);
# }
#
# function drawRelUnit(ren, imageName, labelStr, dateStr, anchorX, anchorY, lblWay, hoverHtml) {
# 	var px = relVal.x + anchorX;
# 	var py = relVal.y + anchorY;
# 	var lblAlign = 'center';
# 	var labelH = 25;
# 	var imgObj = ren.image('../images/caseRelation/' + imageName, px-relVal.imgW/2, py-relVal.imgH/2, relVal.imgW, relVal.imgH).add();// (String source, Number x, Number y, Number width, Number height)
# 	if (hoverHtml){
#         var hoverobj='<div data-placement="bottom" data-toggle="tooltip" title="'+hoverHtml+'" style="width:'+relVal.imgW+';height:'+relVal.imgH+';"></div>';
#         ren.label(hoverobj, px-relVal.imgW/2, py-relVal.imgH/2,null,null,null,true).add();// (str, x, y, shape, anchorX, anchorY, useHTML, baseline, className)
# 		$('[data-toggle="tooltip"]').tooltip();
# 	}
# 	if (!lblWay || lblWay == 1){
# 		py -= relVal.imgH/2+labelH;
# 	} else if (lblWay == 2) {
# 		px += relVal.imgW/2;
# 		py -= relVal.imgH/2;
# 		lblAlign = 'justify';
# 	}
# 	ren.label(labelStr, px, py,null,null,null,true)// (str, x, y, shape, anchorX, anchorY, useHTML, baseline, className)
# 		.attr({
# 			align: lblAlign
# 		})
# 		.css({
#     		fontWeight: 'bold'
# 		}).add();
# }
#
# function drawRelPath(ren, posX_S, posY_S, posX_E, posY_E, hasArrow, hasCorner) {
# 	var strokeW = 10, arrowW = (hasArrow) ? 15 : 0, arrowH = 15;
# 	var arrowSpace = (hasArrow) ? 3 : 0;
# 	var pxS, pyS, pxM, pyM, pxE, pyE;
# 	pxS = relVal.x + posX_S + arrowSpace;
# 	pyS = relVal.y + posY_S;
# 	pxE = relVal.x + posX_E - arrowSpace ;
# 	pyE = relVal.y + posY_E;
# 	if (hasCorner) {
# 		pxM = (hasArrow) ? ((pxS+pxE) /2) : (pxS);
# 		pyM = pyE;
# 		ren.path(['M', pxM, pyS, 'L', pxM, pyM])
# 		.attr({
# 	    	'stroke-width': strokeW,
# 	    	stroke: 'grey'
# 		})
# 		.add();
# 		pxS = pxM-strokeW/2;
# 		pyS = pyM;
# 	}
# 	ren.path(['M', pxS, pyS, 'L', pxE-arrowW-arrowSpace, pyE])
# 	.attr({
#     	'stroke-width': strokeW,
#     	stroke: 'grey'
# 	})
# 	.add();
# 	if (hasArrow) {
# 		ren.path(['M', pxE, pyE, 'L', pxE-arrowW, pyE-arrowH, 'L', pxE - arrowW, pyE + arrowH])
# 		.attr({
# 	    	'stroke-width': 1,
# 	    	stroke: 'black',
# 	    	fill: 'black'
# 		})
# 		.add();
# 	}
# }
#
# function popupSS0201(showType, caseNo, caseNo2, caseType) {
# 	window.open('./SS0201.jsp?showType='+showType+'&caseNo='+caseNo+'&caseNo2='+caseNo2+'&caseType='+caseType,"_blank","","Y");
# }
#
# function gotoSS0201(showType, caseNo, caseNo2, caseType) {
# 	var url = './SS0201.jsp?showType='+showType+'&caseNo='+caseNo+'&caseNo2='+caseNo2+'&caseType='+caseType;
# 	window.open(url, "_self");
# }
#
# function gotoSS0201_SCN11(showType, caseNo, caseNo2, caseType) {
# 	var url = './SS0201.jsp?showType='+showType+'&caseNo='+caseNo+'&caseNo2='+caseNo2+'&caseType='+caseType+'&scrollSCN11=1';
# 	window.open(url, "_self");
# }
#
# function scrollTo_SCN(scnID){
# 	$("#"+scnID+"_detail").show();
# 	$('body').scrollTop( $("#"+scnID).offset().top);
# }
# function setFullVal(jsonObj, id){
# 	var key = Object.keys(jsonObj);
# 	$.each(key, function(i, v) {
# 		$("#"+id+v).html(jsonObj[v]);
# 	});
# }
#
# function showSCN7Item(obj, f){
# 	$(obj).hide();
# 	if(f){
# 		$(obj).next().show();
# 		$(obj).closest('tr').next().show();
# 	}else{
# 		$(obj).prev().show();
# 		$(obj).closest('tr').next().hide();
# 	}
# }
#
# function showSCN(f){
# 	$.each(scnShow, function(i, v) {
# 		if(f)	$("#"+v).show();
# 		else	$("#"+v).hide();
# 	});
# }
# function doTimeDiagram1(type, data){
# 	var datumNum = getDatumNum1(type);
#     $("#SCN3_diagram").highcharts({
#         chart: {
# 			width: timeVal.sizeW,
# 			height: timeVal.sizeH,
#             backgroundColor: 'white',
#             events: {
#                 load: function () {
#
#                     var ren = this.renderer;
#
#                     drawTimeBGLine(ren, datumNum.caseFlowLine);
#
#                     drawTimeUnit(ren, 'icon_applDate.png', $("#scn3_applDate").text(), data.applDate, 0, 0);
#                     if(type != "1"){
#
#                      	drawTimeUnit(ren, 'icon_finishDate.png', $("#scn3_finishDate").text(), data.finishDate, datumNum.finishLine, 0);
#     					if(type == "3" || type == "4" || type == "5"){
#
#                          	drawTimeUnit(ren, 'icon_regNoticeDate.png', $("#scn3_rejNoticeDate").text(), data.rejNoticeDate, datumNum.rejNoticeLine, 0);
#     					}
#     					if(type == "5" && data.oppMsg){
#
#     						drawTimeMarkPath(ren, data.oppMsg, tLineW*0.7, 0, $("#scn3_appeal").text());
#     					}
#                     }
# 					if(type != "4"){
# 	                    if(1 == 2){
# 	                    	ren.image('../images/timing/icon_currentDateE.png', timeVal.x + (datumNum.caseFlowLine-25), timeVal.y - 70, 50, 70).add();
# 	                	}else{
# 	                		ren.image('../images/timing/icon_currentDate.png', timeVal.x + (datumNum.caseFlowLine-25), timeVal.y - 70, 50, 70).add();
# 	                	}
# 					}
#                 }
#             }
#         },
#         title: {
#             text: ''
#         }
#     });
#     $("#SCN3").show();
# }
#
# function doTimeDiagram2(type, data){
# 	var today = "110/04/12";
# 	var tuneExtendedApplDateLine = data.extendedApplDate.localeCompare(today);
# 	var datumNum = getDatumNum2(type, tuneExtendedApplDateLine);
#     $("#SCN3_diagram").highcharts({
#         chart: {
# 			width: timeVal.sizeW,
# 			height: timeVal.sizeH,
#             backgroundColor: 'white',
#             events: {
#                 load: function () {
#
#                     var ren = this.renderer;
#
#                     drawTimeBGLine(ren, datumNum.caseFlowLine);
#
#                     drawTimeUnit(ren, 'icon_applDate.png', $("#scn3_applDate").text(), data.applDate, 0, 0);
# 					if(type == "9" || type == "10"){
#
# 	                    drawTimeUnit(ren, 'icon_extendedDeadline_01.png', $("#scn3_examNoticeDate").text(), data.examNoticeDate, tLineW*0.2, 0);
# 					}else{
#
# 	                    drawTimeUnit(ren, 'icon_oppDeadline_'+datumNum.oppDeadlineType+'.png', $("#scn3_oppDeadline").text(), data.oppDeadline, tLineW*0.6, 0);
# 					}
#
#                     drawTimeUnit(ren, 'icon_regNoticeDate.png', $("#scn3_regNoticeDate").text(), data.regNoticeDate, tLineW*0.4, 0);
# 					if(type == "3" || type == "4"){
#
# 	                    drawTimeUnit(ren, 'icon_deadline_'+datumNum.deadlineType+'.png', $("#scn3_deadline").text(), data.deadline, tLineW*0.8, 0);
# 						if(type == "3"){
#
# 		                    drawTimeUnit(ren, 'icon_extendedDeadline_'+datumNum.extendedDeadlineType+'.png', $("#scn3_extendedDeadline").text(), data.extendedDeadline, tLineW, 0);
# 						}else if(data.extendedMsg){
#
# 							drawTimeMarkPath(ren, data.extendedMsg, datumNum.extendedLine, 0, $("#scn3_extendedLine").text());
# 						}
# 					}else{
#
# 	                    drawTimeUnit(ren, 'icon_deadline_'+datumNum.deadlineType+'.png', $("#scn3_deadline").text(), data.deadline, tLineW, 0);
# 					}
# 					if((type == "6" || type == "7") && data.oppMsg){
#
# 						drawTimeMarkPath(ren, data.oppMsg, datumNum.oppLine, 0, $("#scn3_oppLine").text());
# 					}else if(type == "8" || type == "9"){
#
# 						var tempMsg = "";
# 						var msgArr = [data.examMsg, data.applDelMsg, data.issueOppMsg];
# 						for (var i=0;i<msgArr.length;i++)
# 							if (msgArr[i])
# 								tempMsg += (tempMsg.length == 0) ? msgArr[i] : "/<br>" + msgArr[i];
# 						if (tempMsg != "")
# 							drawTimeMarkPath(ren, tempMsg, datumNum.oppLine, 0, $("#scn3_oppLine").text());
# 					}
#
# 					var msg_extendApplDate = $("#scn3_extendedApplDateLine").text() +"<br>"+data.extendedApplDate;
# 					drawTimeMarkPathNoLink(ren, msg_extendApplDate, datumNum.extendedApplDateLine, 0, msg_extendApplDate);
# 					if(type != "5"){
# 	                	if(1 == 2){
# 	                		ren.image('../images/timing/icon_currentDateE.png', timeVal.x + datumNum.caseFlowLine - 25, timeVal.y - 70, 50, 70).add();
# 	                	}else{
# 	                		ren.image('../images/timing/icon_currentDate.png', timeVal.x + datumNum.caseFlowLine - 25, timeVal.y - 70, 50, 70).add();
# 	                	}
# 					}
#                 }
#             }
#         },
#         title: {
#             text: ''
#         }
#     });
#     $("#SCN3").show();
# }
#
# function drawTimeBGLine(ren, caseFlowLineW) {
# 	var strokeW = 8, arrowW = 9, arrowH = 9;
# 	var pxS = timeVal.x,
# 		pyS = timeVal.y,
# 		pxE = pxS + tLineW,
# 		pyE = pyS;
#
# 	ren.path(['M', pxS, pyS, 'L', pxE-arrowW, pyE])
# 		.attr({
# 	    	'stroke-width': strokeW,
# 	    	stroke: 'silver'
# 		})
# 		.add();
#
# 	ren.path(['M', pxE, pyE, 'L', pxE-arrowW, pyE-arrowH, 'L', pxE - arrowW, pyE + arrowH])
# 		.attr({
# 	    	'stroke-width': 1,
# 	    	stroke: 'silver',
# 	    	fill: 'silver'
# 		})
# 		.add();
#
# 	pxE=pxS+caseFlowLineW;
# 	pxE=(tLineW == caseFlowLineW)?pxE-arrowW:pxE;
# 	ren.path(['M', pxS, pyS, 'L', pxE, pyE])
# 		.attr({
# 	    	'stroke-width': strokeW,
# 	    	stroke: 'black'
# 		})
# 		.add();
# }
#
# function drawTimeUnit(ren, imageName, labelStr, dateStr, anchorX, anchorY) {
# 	var posX = timeVal.x + anchorX;
# 	var posY = timeVal.y + anchorY;
# 	var imgOffsetY = -5, labelH = 20;
# 	ren.image('../images/timing/' + imageName, posX-timeVal.imgW/2, posY-timeVal.imgH/2 + imgOffsetY, timeVal.imgW, timeVal.imgH).add();
# 	ren.label(labelStr, posX, posY + timeVal.imgH/2)
# 		.attr({
# 			align: 'center'
# 		})
# 		.css({
#     		fontWeight: 'bold'
# 		}).add();
# 	ren.label(dateStr, posX, posY + timeVal.imgH/2 + labelH)
# 		.attr({
# 			align: 'center'
# 		})
# 		.css({
#     		fontWeight: 'bold'
# 		}).add();
# }
#
# function drawTimeMarkPath(ren, labelStr, posX_S, posY_S, clickAlertStr) {
#
# 	if (false) labelStr = clickAlertStr;
# 	var posX = timeVal.x + posX_S;
# 	var posY = timeVal.y + posY_S;
# 	ren.path(['M', posX, posY, 'L', posX, posY + timeVal.levelH])//M(MoveTo), L(LineTo)
# 	    .attr({
# 	        'stroke-width': 2
# 	        ,stroke: 'silver'
# 	        ,dashstyle: 'dash'
# 	        ,align: 'center'
# 	    })
# 	    .add();
#
# 	if($("#showType").val() == '3'){
# 		labelStr = '<a href=\'javascript:scrollTo_SCN("SCN9");\'>'+labelStr+'</a>';
# 	}else{
# 		labelStr = '<a href=\'javascript:scrollTo_SCN("SCN10");\'>'+labelStr+'</a>';
# 	}
#
# 	ren.label(labelStr, posX, posY + timeVal.levelH,null,null,null,true)
# 		.attr({
# 			align: 'center'
# 		})
# 		.css({
# 			color: 'blue'
# 			,fontWeight: 'bold'
# 			,textDecoration: 'underline'
# 		})
# 		.add();
# }
#
#
# function drawTimeMarkPathNoLink(ren, labelStr, posX_S, posY_S, clickAlertStr) {
# 	var posX = timeVal.x + posX_S;
# 	var posY = timeVal.y + posY_S;
# 	ren.path(['M', posX, posY, 'L', posX, posY + timeVal.levelH + 15])
# 	    .attr({
# 	        'stroke-width': 2
# 	        ,stroke: 'silver'
# 	        ,dashstyle: 'dash'
# 	        ,align: 'center'
# 	    })
# 	    .add();
#
# 	ren.label(labelStr, posX, posY + timeVal.levelH + 15,null,null,null,true)
# 		.attr({
# 			align: 'center'
# 		})
# 		.css({
# 			color: 'black'
# 			,fontWeight: 'bold'
# 		})
# 		.add();
# }
# function getDatumNum1(type){
# 	var datumNum = {};
# 	switch (parseInt(type)){
# 		case 1:
# 			datumNum.caseFlowLine = tLineW*0.2;
#         	break;
#     	case 2:
# 			datumNum.caseFlowLine = tLineW*0.8;
# 			datumNum.finishLine = tLineW*0.6;
#         	break;
#     	case 3:
#     	case 5:
#     		datumNum.caseFlowLine = tLineW*0.8;
# 			datumNum.finishLine = tLineW*0.3;
# 			datumNum.rejNoticeLine = tLineW*0.5;
#         	break;
#     	case 4:
# 			datumNum.caseFlowLine = tLineW;
# 			datumNum.rejNoticeLine = tLineW;
# 			datumNum.finishLine = tLineW*0.7;
#         	break;
#     	default:
#     		datumNum.caseFlowLine = 0;
# 	}
# 	return datumNum;
# }
# function testSCN3(data) {
#
# }
# function getDatumNum2(type, tuneExtendedApplDateLine){
# 	var datumNum = {};
# 	switch (parseInt(type)){
# 		case 1:
# 			datumNum.caseFlowLine = tLineW*0.5;
# 			datumNum.extendedApplDateLine = tLineW*0.9;
# 			datumNum.oppDeadlineType = "02";
# 			datumNum.deadlineType = "02";
#         	break;
#     	case 2:
#     		datumNum.caseFlowLine = tLineW*0.9;
#     		datumNum.extendedApplDateLine = tuneDateLinePosition(tuneExtendedApplDateLine, tLineW*0.85, tLineW*0.92, datumNum.caseFlowLine);
# 			datumNum.oppDeadlineType = "01";
# 			datumNum.deadlineType = "02";
#         	break;
#     	case 3:
#     		datumNum.caseFlowLine = tLineW*0.9;
#     		datumNum.extendedApplDateLine = tLineW*0.7;
# 			datumNum.oppDeadlineType = "01";
# 			datumNum.deadlineType = "01";
# 			datumNum.extendedDeadlineType = "02";
#         	break;
#     	case 4:
#     		datumNum.caseFlowLine = tLineW*0.9;
# 			datumNum.extendedLine = tLineW*0.9;
# 			datumNum.extendedApplDateLine = tLineW*0.7;
# 			datumNum.oppDeadlineType = "01";
# 			datumNum.deadlineType = "01";
#         	break;
#     	case 5:
#     		datumNum.caseFlowLine = tLineW;
#     		datumNum.extendedApplDateLine = tLineW*0.9;
#     		datumNum.oppDeadlineType = "01";
#     		datumNum.deadlineType = "01";
#         	break;
# 		case 6:
# 			datumNum.caseFlowLine = tLineW*0.5;
# 			datumNum.oppLine = tLineW*0.48;
# 			datumNum.extendedApplDateLine = tLineW*0.9;
# 			datumNum.oppDeadlineType = "02";
# 			datumNum.deadlineType = "02";
#         	break;
# 		case 7:
# 			datumNum.caseFlowLine = tLineW*0.7;
# 			datumNum.oppLine = tLineW*0.48;
# 			datumNum.extendedApplDateLine = tuneDateLinePosition(tuneExtendedApplDateLine, tLineW*0.67, tLineW*0.9, datumNum.caseFlowLine);
# 			datumNum.oppDeadlineType = "01";
# 			datumNum.deadlineType = "02";
#         	break;
# 		case 8:
# 			datumNum.caseFlowLine = tLineW*0.8;
# 			datumNum.oppLine = tLineW*0.67;
# 			datumNum.extendedApplDateLine = tuneDateLinePosition(tuneExtendedApplDateLine, tLineW*0.78, tLineW*0.9, datumNum.caseFlowLine);
# 			datumNum.oppDeadlineType = "01";
# 			datumNum.deadlineType = "02";
#         	break;
# 		case 9:
# 			datumNum.caseFlowLine = tLineW*0.8;
# 			datumNum.oppLine = tLineW*0.67;
# 			datumNum.extendedApplDateLine = tuneDateLinePosition(tuneExtendedApplDateLine, tLineW*0.78, tLineW*0.9, datumNum.caseFlowLine);
# 			datumNum.deadlineType = "02";
#         	break;
# 		case 10:
# 			datumNum.caseFlowLine = tLineW*0.8;
# 			datumNum.deadlineType = "02";
# 			datumNum.extendedApplDateLine = tuneDateLinePosition(tuneExtendedApplDateLine, tLineW*0.75, tLineW*0.9, datumNum.caseFlowLine);
#         	break;
#     	default:
#     		datumNum.caseFlowLine = 0;
# 	}
#
# 	return datumNum;
# }
#
# function tuneDateLinePosition(tuneLine, forwardPos, backPos, defaultPos) {
# 	switch(tuneLine) {
# 	case -1:
# 		return forwardPos;
# 	case 0:
# 		return defaultPos;
# 	case 1:
# 		return backPos;
# 	}
# }
#   </script>
#  </body>
# </html>
#
# {'Server': 'nginx/1.12.0', 'Date': 'Mon, 12 Apr 2021 03:34:52 GMT', 'Content-Type': 'text/html;charset=UTF-8', 'Connection': 'keep-alive', 'X-Powered-By': 'XXXXXXXXXXX, XXXXXXXX', 'Set-Cookie': 'JSESSIONID=VMl_PUjF4QDdPcfFO95EPzeMN1Qe9I9cnZDOd6cL.un082idz; path=/, cookiesession1=678B287198901234ABCDFGHIJKLMEFB2;Expires=Tue, 12 Apr 2022 03:34:52 GMT;Path=/;HttpOnly', 'Content-Language': 'zh-TW', 'Expires': 'Mon, 12 Apr 2021 03:34:51 GMT', 'Cache-Control': 'no-cache, no-cache', 'Pragma': 'no-cache', 'content-length': '64802'}

# %%
para = {'caseNo':"XpJ13RyT4NFE3cEJsbnV1QTZSeDhldmVtT1F3QT09",'showType':"2",'caseType':"1",'l6':"zh_TW",'isReadBulletinen_US':"",'isReadBulletinzh_TW':"true"}
#104056467
html = requests.get(url = "https://twtmsearch.tipo.gov.tw/SS0/friendlyPrinting",params = para)
print(html.url)
soup = BeautifulSoup(html.text, 'html.parser')
print(soup.prettify())
x = html.text
with open ("m.html","w",encoding="UTF-8") as f:
    f.write(x)
# Out:
# https://twtmsearch.tipo.gov.tw/SS0/friendlyPrinting?caseNo=XpJ13RyT4NFE3cEJsbnV1QTZSeDhldmVtT1F3QT09&showType=2&caseType=1&l6=zh_TW&isReadBulletinen_US=&isReadBulletinzh_TW=true
# <html>
#  <head>
#   <title>
#    404 Page not found
#   </title>
#   <title>
#    智慧局商標檢索系統
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="-1" http-equiv="Expires">
#    <meta content="no-cache" http-equiv="pragma"/>
#    <meta content="no-cache" http-equiv="Cache-control"/>
#    <meta content="智慧局商標檢索系統" name="keywords"/>
#    <link href="/css/default.css;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz" rel="stylesheet" type="text/css"/>
#    <link href="/js/jquery-window-5.0.4/css/jquery.window.css;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz" rel="stylesheet" type="text/css"/>
#    <link href="/favicon.ico;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz" rel="shortcut icon"/>
#    <script src="/jqwidgets/scripts/jquery-1.11.1.min.js;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz">
#    </script>
#    <script src="/js/tablesort.js;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz" type="text/javascript">
#    </script>
#    <script src="/js/validate.js;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz" type="text/javascript">
#    </script>
#    <script src="/js/function.js;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz" type="text/javascript">
#    </script>
#    <script src="/js/json.js;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz" type="text/javascript">
#    </script>
#    <script src="/js/jquery/jquery-cookie.js;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz" type="text/javascript">
#    </script>
#    <script src="/js/commonUtils.js;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz" type="text/javascript">
#    </script>
#    <script src="/js/md5.js;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz" type="text/javascript">
#    </script>
#    <script src="/js/handlebars-v4.0.2.js;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz" type="text/javascript">
#    </script>
#    <script src="/js/lb0901.js;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz" type="text/javascript">
#    </script>
#    <script src="/js/jquery-window-5.0.4/jquery.window.min.js;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz" type="text/javascript">
#    </script>
#    <script src="/js/tcfifunction.js;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz" type="text/javascript">
#    </script>
#    <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#    <meta content="-1" http-equiv="Expires">
#     <meta content="no-cache" http-equiv="pragma"/>
#     <meta content="no-cache" http-equiv="Cache-control"/>
#     <script src="/bower_components/bootstrap/dist/js/bootstrap.min.js;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz">
#     </script>
#     <script src="/bower_components/bootstrap-material-design/dist/js/ripples.min.js;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz">
#     </script>
#     <script src="/bower_components/bootstrap-material-design/dist/js/material.min.js;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz">
#     </script>
#     <script src="/bower_components/momentjs/min/moment.min.js;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz">
#     </script>
#     <script src="/bower_components/bootstrap-material-datetimepicker/js/bootstrap-material-datetimepicker.js;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz">
#     </script>
#     <script src="/bower_components/moment/min/moment-with-locales.min.js;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz" type="text/javascript">
#     </script>
#     <script src="/bower_components/eonasdan-bootstrap-datetimepicker/build/js/bootstrap-datetimepicker.min.js;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz" type="text/javascript">
#     </script>
#     <script src="/bower_components/sweetalert/dist/sweetalert.min.js;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz" type="text/javascript">
#     </script>
#     <script src="/bower_components/feedback/js/feedback.js;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz">
#     </script>
#     <script src="/js/jquery/jquery.blockUI.js;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz" type="text/javascript">
#     </script>
#     <link href="/bower_components/bootstrap/dist/css/bootstrap.min.css;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz" rel="stylesheet" type="text/css"/>
#     <link href="/bower_components/bootstrap-material-design/dist/css/roboto.min.css;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz" rel="stylesheet" type="text/css"/>
#     <link href="/bower_components/bootstrap-material-design/dist/css/material.min.css;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz" rel="stylesheet" type="text/css"/>
#     <link href="/bower_components/bootstrap-material-design/dist/css/ripples.min.css;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz" rel="stylesheet" type="text/css"/>
#     <link href="/bower_components/bootstrap-material-design/dist/css/custom.css;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz" rel="stylesheet" type="text/css"/>
#     <link href="/bower_components/bootstrap-material-datetimepicker/css/bootstrap-material-datetimepicker.css;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz" rel="stylesheet" type="text/css"/>
#     <link href="/bower_components/feedback/css/feedback.css;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz" rel="stylesheet" type="text/css"/>
#     <link href="/bower_components/eonasdan-bootstrap-datetimepicker/build/css/bootstrap-datetimepicker.min.css;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz" rel="stylesheet" type="text/css">
#      <link href="/bower_components/bootstrap-material-design/dist/css/fonts.css;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz?family=Roboto:400,500" rel="stylesheet" type="text/css"/>
#      <link href="/bower_components/bootstrap-material-design/dist/css/icon.css;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz?family=Material+Icons" rel="stylesheet" type="text/css"/>
#      <link href="/bower_components/sweetalert/dist/sweetalert.css;jsessionid=_rLAzVvnmY8jIEhf2q5Ql9g6dnwl9pF2Q9LbshKO.un081idz" rel="stylesheet" type="text/css"/>
#     </link>
#    </meta>
#   </meta>
#  </head>
#  <body>
#   <div class="home-header header-panel shadow-z-2">
#    <div class="container">
#     <div class="row">
#      <div class="col-xs-6">
#       <h1>
#        遠端商標檢索系統
#       </h1>
#      </div>
#      <div class="col-xs-6">
#       <div>
#       </div>
#      </div>
#     </div>
#     <p class="text-muted text-right data-update-time">
#     </p>
#    </div>
#   </div>
#   <legend>
#    <br/>
#    <br/>
#    <br/>
#    404 網頁不存在(404 Page not found)！
#    <a href="javascript:history.back();">
#     回上頁(Go back)！！
#    </a>
#    <br/>
#    <br/>
#   </legend>
#   <footer class="footer-distributed">
#    <div class="footer-left">
#     <p class="footer-links">
#      <a href="#">
#       智慧財產局版權所有
#      </a>
#      <img src="/images/copyright.png"/>
#      <span class="right">
#       最佳瀏覽器建議IE11以上解析度 1024 x 768
#      </span>
#      <br/>
#      <a href="#">
#       地址：台北市辛亥路二段185號3樓
#      </a>
#      <a href="#">
#       資料服務組服務台：(02)23767164、(02)23767165、(02)23767166
#      </a>
#      <span class="text-right">
#       來訪人數：00041578767
#      </span>
#     </p>
#    </div>
#   </footer>
#  </body>
# </html>

# %%
s = "XpJ13RyT4NFE3cEJsbnV1QTZSeDhldmVtT1F3QT09"
b = "XpJ13RyT4Sm5hSU8xNm9hbFNSeDhldmVtT1F3QT09"
c = "XpJ13RyT4bTZOTG5DY0dGNHRlTDZiZDM0RVM1QT09"
print(len("bTZOTG5DY0dGNHRlTDZiZDM0RVM1"))
104056467
103047283
110002654
#https://twtmsearch.tipo.gov.tw/SS0/SS0201.jsp?showType=2&caseNo=XpJ13RyT4eFFXcjVIM0lzRTZSeDhldmVtT1F3QT09&caseType=1
#https://twtmsearch.tipo.gov.tw/OS0/OS0401_SCN3.jsp?issueNo=XpJ13RyT4VWh5aEQ2UFNZYTRRNnN0c2E5bFY5UT09&l6=zh_TW&isReadBulletinen_US=&isReadBulletinzh_TW=true
# Out:
# 28
# 110002654

# %%
def gethtmlbycode(casenocode):
    url = "https://twtmsearch.tipo.gov.tw/SS0/friendlyPrinting.jsp?showType=2&caseType=1&caseNo=%s&caseNo2=&l6=zh_TW&isReadBulletinen_US=&isReadBulletinzh_TW=true"%casenocode
    #print(url)
    html = requests.get(url = url)
    soup = BeautifulSoup(html.text, 'html.parser')
    #print(soup.prettify())
    x = html.text
    with open ("result.html","w",encoding="UTF-8") as f:
        f.write(x)
casenocode = "XpJ13RyT4ZDZYM0RBdUl1MnlSeDhldmVtT1F3QT09"
gethtmlbycode(casenocode)

# %%
#https://twtmsearch.tipo.gov.tw/SS0/friendlyPrinting.jsp?showType=3&caseType=&caseNo=XpJ13RyT4OS9ZNU5LamRpb2FSeDhldmVtT1F3QT09&caseNo2=XpJ13RyT4TWtxQW44aitmdVpYREgxVVkraE9kdz09&l6=zh_TW&isReadBulletinen_US=&isReadBulletinzh_TW=true

# %%
def gethtmlbycodereject(casenocode,casenocode2):
    url = "https://twtmsearch.tipo.gov.tw/SS0/friendlyPrinting.jsp?showType=3&caseType=&caseNo=%s&caseNo2=%s&l6=zh_TW&isReadBulletinen_US=&isReadBulletinzh_TW=true"%(casenocode,casenocode2)
    #print(url)
    html = requests.get(url = url)
    soup = BeautifulSoup(html.text, 'html.parser')
    #print(soup.prettify())
    x = html.text
    with open ("result.html","w",encoding="UTF-8") as f:
        f.write(x)
casenocode = "XpJ13RyT4OS9ZNU5LamRpb2FSeDhldmVtT1F3QT09"
casenocode2 = "XpJ13RyT4TWtxQW44aitmdVpYREgxVVkraE9kdz09"
gethtmlbycodereject(casenocode,casenocode2)
